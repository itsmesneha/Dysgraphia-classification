# %% [markdown]
# ## Import libraries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## Load and preprocess the Data (Using Image Data Generator)

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory('Final-data/train/',
                                                    target_size=(224, 224),
                                                    batch_size=32,
                                                    class_mode='categorical')

valid_datagen = ImageDataGenerator(rescale=1./255)
valid_generator = valid_datagen.flow_from_directory('Final-data/validation/',
                                                    target_size=(224, 224),
                                                    batch_size=32,
                                                    class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory('Final-data/test/',
                                                  target_size=(224, 224),
                                                  batch_size=32,
                                                  class_mode='categorical')
# Out:
# Found 198 images belonging to 2 classes.
# Found 25 images belonging to 2 classes.
# Found 26 images belonging to 2 classes.

# %% [markdown]
# ## Build the Model

# %%
#2-layered model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(2, activation='softmax')  # Assuming 2 classes: potential and low potential dysgraphia
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 186624)            0
#
#  dense (Dense)               (None, 64)                11944000
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 11963522 (45.64 MB)
# Trainable params: 11963522 (45.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Compile the Model

# %%
model.compile(optimizer=Adam(), loss='categorical_crossentropy', 
              metrics=['accuracy', Precision(), Recall()])

# %% [markdown]
# ## Train and Save the best model

# %%
checkpoint = ModelCheckpoint('best_model_layer2.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(train_generator, epochs=100, validation_data=valid_generator,callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 7/7 [==============================] - ETA: 0s - loss: 2.9790 - accuracy: 0.5202 - precision: 0.5202 - recall: 0.5202
# Epoch 1: val_accuracy improved from -inf to 0.44000, saving model to best_model_layer2.h5
# C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 42s 4s/step - loss: 2.9790 - accuracy: 0.5202 - precision: 0.5202 - recall: 0.5202 - val_loss: 0.7893 - val_accuracy: 0.4400 - val_precision: 0.4400 - val_recall: 0.4400
# Epoch 2/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6749 - accuracy: 0.5859 - precision: 0.5859 - recall: 0.5859
# Epoch 2: val_accuracy did not improve from 0.44000
# 7/7 [==============================] - 18s 3s/step - loss: 0.6749 - accuracy: 0.5859 - precision: 0.5859 - recall: 0.5859 - val_loss: 0.7596 - val_accuracy: 0.3600 - val_precision: 0.3600 - val_recall: 0.3600
# Epoch 3/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5778 - accuracy: 0.6162 - precision: 0.6162 - recall: 0.6162
# Epoch 3: val_accuracy improved from 0.44000 to 0.48000, saving model to best_model_layer2.h5
# 7/7 [==============================] - 16s 2s/step - loss: 0.5778 - accuracy: 0.6162 - precision: 0.6162 - recall: 0.6162 - val_loss: 0.6434 - val_accuracy: 0.4800 - val_precision: 0.4800 - val_recall: 0.4800
# Epoch 4/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5140 - accuracy: 0.8485 - precision: 0.8485 - recall: 0.8485
# Epoch 4: val_accuracy improved from 0.48000 to 0.68000, saving model to best_model_layer2.h5
# 7/7 [==============================] - 20s 3s/step - loss: 0.5140 - accuracy: 0.8485 - precision: 0.8485 - recall: 0.8485 - val_loss: 0.5584 - val_accuracy: 0.6800 - val_precision: 0.6800 - val_recall: 0.6800
# Epoch 5/100
# 7/7 [==============================] - ETA: 0s - loss: 0.3814 - accuracy: 0.8737 - precision: 0.8737 - recall: 0.8737
# Epoch 5: val_accuracy did not improve from 0.68000
# 7/7 [==============================] - 14s 2s/step - loss: 0.3814 - accuracy: 0.8737 - precision: 0.8737 - recall: 0.8737 - val_loss: 0.5273 - val_accuracy: 0.6000 - val_precision: 0.6000 - val_recall: 0.6000
# Epoch 6/100
# 7/7 [==============================] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 14s 2s/step - loss: 3.2105e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3253 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 62/100
# 7/7 [==============================] - ETA: 0s - loss: 3.1092e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 62: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 14s 2s/step - loss: 3.1092e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3251 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 63/100
# 7/7 [==============================] - ETA: 0s - loss: 3.0199e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 63: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 3.0199e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3251 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 64/100
# 7/7 [==============================] - ETA: 0s - loss: 2.9308e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 64: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 21s 3s/step - loss: 2.9308e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3252 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 65/100
# 7/7 [==============================] - ETA: 0s - loss: 2.8451e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 65: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 2.8451e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3261 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 66/100
# 7/7 [==============================] - ETA: 0s - loss: 2.7684e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 66: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 2.7684e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3268 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 67/100
# 7/7 [==============================] - ETA: 0s - loss: 2.6845e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 67: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 21s 3s/step - loss: 2.6845e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3269 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 68/100
# 7/7 [==============================] - ETA: 0s - loss: 2.6085e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 68: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 16s 2s/step - loss: 2.6085e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3275 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 69/100
# 7/7 [==============================] - ETA: 0s - loss: 2.5339e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 69: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 2.5339e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3281 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 70/100
# 7/7 [==============================] - ETA: 0s - loss: 2.4638e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 70: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 16s 2s/step - loss: 2.4638e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3286 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 71/100
# 7/7 [==============================] - ETA: 0s - loss: 2.3979e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 71: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 2.3979e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3298 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 72/100
# 7/7 [==============================] - ETA: 0s - loss: 2.3320e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 72: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 16s 2s/step - loss: 2.3320e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3309 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 73/100
# 7/7 [==============================] - ETA: 0s - loss: 2.2680e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 73: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 2.2680e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3311 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 74/100
# 7/7 [==============================] - ETA: 0s - loss: 2.2127e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 74: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 2.2127e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3306 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 75/100
# 7/7 [==============================] - ETA: 0s - loss: 2.1476e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 75: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 2.1476e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3323 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 76/100
# 7/7 [==============================] - ETA: 0s - loss: 2.0928e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 76: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 2.0928e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3341 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 77/100
# 7/7 [==============================] - ETA: 0s - loss: 2.0253e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 77: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 2.0253e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3333 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 78/100
# 7/7 [==============================] - ETA: 0s - loss: 1.9698e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 78: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 1.9698e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3343 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 79/100
# 7/7 [==============================] - ETA: 0s - loss: 1.9182e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 79: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 1.9182e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3355 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 80/100
# 7/7 [==============================] - ETA: 0s - loss: 1.8630e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 80: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 1.8630e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3366 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 81/100
# 7/7 [==============================] - ETA: 0s - loss: 1.8108e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 81: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 1.8108e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3375 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 82/100
# 7/7 [==============================] - ETA: 0s - loss: 1.7659e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 82: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 1.7659e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3376 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 83/100
# 7/7 [==============================] - ETA: 0s - loss: 1.7186e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 83: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 1.7186e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3383 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 84/100
# 7/7 [==============================] - ETA: 0s - loss: 1.6722e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 84: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 1.6722e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3381 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 85/100
# 7/7 [==============================] - ETA: 0s - loss: 1.6282e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 85: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 1.6282e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3387 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 86/100
# 7/7 [==============================] - ETA: 0s - loss: 1.5818e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 86: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 1.5818e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3403 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 87/100
# 7/7 [==============================] - ETA: 0s - loss: 1.5367e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 87: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 1.5367e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3413 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 88/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4942e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 88: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 17s 2s/step - loss: 1.4942e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3422 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 89/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4522e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 89: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 16s 2s/step - loss: 1.4522e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3430 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 90/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4144e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 90: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 17s 2s/step - loss: 1.4144e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3448 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 91/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3738e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 91: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 15s 2s/step - loss: 1.3738e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3461 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 92/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3378e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 92: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 14s 2s/step - loss: 1.3378e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3485 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 93/100
# 7/7 [==============================] - ETA: 0s - loss: 1.2827e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 93: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 13s 2s/step - loss: 1.2827e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3487 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 94/100
# 7/7 [==============================] - ETA: 0s - loss: 1.2485e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 94: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 14s 2s/step - loss: 1.2485e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3510 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 95/100
# 7/7 [==============================] - ETA: 0s - loss: 1.2040e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 95: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 14s 2s/step - loss: 1.2040e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3526 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 96/100
# 7/7 [==============================] - ETA: 0s - loss: 1.1696e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 96: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 14s 2s/step - loss: 1.1696e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3520 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 97/100
# 7/7 [==============================] - ETA: 0s - loss: 1.1286e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 97: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 14s 2s/step - loss: 1.1286e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3524 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 98/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0991e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 98: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 14s 2s/step - loss: 1.0991e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3540 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 99/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0688e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 99: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 14s 2s/step - loss: 1.0688e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3556 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600
# Epoch 100/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0378e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 100: val_accuracy did not improve from 0.96000
# 7/7 [==============================] - 14s 2s/step - loss: 1.0378e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3551 - val_accuracy: 0.9600 - val_precision: 0.9600 - val_recall: 0.9600

# %% [markdown]
# ## Evaluate the Model

# %%
model.load_weights('best_model_layer2.h5')
test_loss, test_acc ,test_prec, test_recall= model.evaluate(test_generator)
print("Test Accuracy:", test_acc)
print("Test Precision:", test_prec)
print("Test F1-score:", test_recall)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.5095 - accuracy: 0.7692 - precision: 0.7692 - recall: 0.7692
# Test Accuracy: 0.7692307829856873
# Test Precision: 0.7692307829856873
# Test F1-score: 0.7692307829856873

# %% [markdown]
# ## Model Metrics

# %%
Y_pred = model.predict(test_generator)
y_pred = tf.argmax(Y_pred, axis=1)
print("Classification Report:\n", classification_report(test_generator.classes, y_pred.numpy()))
# Out:
# 1/1 [==============================] - 8s 8s/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.58      0.65      0.61        17
#            1       0.14      0.11      0.12         9
#
#     accuracy                           0.46        26
#    macro avg       0.36      0.38      0.37        26
# weighted avg       0.43      0.46      0.44        26

# %%
from sklearn.metrics import confusion_matrix, classification_report
conf_matrix = confusion_matrix(test_generator.classes, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[11  6]
#  [ 8  1]]

# %% [markdown]
# ## Visualize

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 3))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
def plot_precision_recall(history):
    plt.figure(figsize=(12, 3))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history['precision'], label='Training Precision')
    plt.plot(history.history['val_precision'], label='Validation Precision')
    plt.xlabel('Epoch')
    plt.ylabel('Precision')
    plt.title('Training and Validation Precision')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['recall'], label='Training Recall')
    plt.plot(history.history['val_recall'], label='Validation Recall')
    plt.xlabel('Epoch')
    plt.ylabel('Recall')
    plt.title('Training and Validation Recall')
    plt.legend()

    plt.show()

plot_precision_recall(history)
