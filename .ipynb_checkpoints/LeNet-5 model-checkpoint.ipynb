# %% [markdown]
# ## Import libraries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## Load and preprocess the Data (Using Image Data Generator)

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory('Final-data/train/',
                                                    target_size=(224, 224),
                                                    batch_size=32,
                                                    class_mode='categorical')

valid_datagen = ImageDataGenerator(rescale=1./255)
valid_generator = valid_datagen.flow_from_directory('Final-data/validation/',
                                                    target_size=(224, 224),
                                                    batch_size=32,
                                                    class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory('Final-data/test/',
                                                  target_size=(224, 224),
                                                  batch_size=32,
                                                  class_mode='categorical')
# Out:
# Found 198 images belonging to 2 classes.
# Found 25 images belonging to 2 classes.
# Found 26 images belonging to 2 classes.

# %% [markdown]
# ## Build the Model

# %%
#LeNet 5 model
model = Sequential([
    Conv2D(6, kernel_size=(5, 5), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(16, kernel_size=(5, 5), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(120, activation='relu'),
    Dense(84, activation='relu'),
    Dense(2, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 220, 220, 6)       456
#
#  max_pooling2d (MaxPooling2  (None, 110, 110, 6)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 106, 106, 16)      2416
#
#  max_pooling2d_1 (MaxPoolin  (None, 53, 53, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 44944)             0
#
#  dense (Dense)               (None, 120)               5393400
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 2)                 170
#
# =================================================================
# Total params: 5406606 (20.62 MB)
# Trainable params: 5406606 (20.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Compile the Model

# %%
model.compile(optimizer=Adam(), loss='categorical_crossentropy', 
              metrics=['accuracy', Precision(), Recall()])

# %% [markdown]
# ## Train and Save the best model

# %%
checkpoint = ModelCheckpoint('best_model_LeNet.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(train_generator, epochs=100, validation_data=valid_generator,callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0106 - accuracy: 0.5909 - precision: 0.5909 - recall: 0.5909
# Epoch 1: val_accuracy improved from -inf to 0.80000, saving model to best_model_LeNet.h5
# C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 15s 2s/step - loss: 1.0106 - accuracy: 0.5909 - precision: 0.5909 - recall: 0.5909 - val_loss: 0.5431 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.8000
# Epoch 2/100
# 7/7 [==============================] - ETA: 0s - loss: 0.4140 - accuracy: 0.8182 - precision: 0.8182 - recall: 0.8182
# Epoch 2: val_accuracy did not improve from 0.80000
# 7/7 [==============================] - 7s 966ms/step - loss: 0.4140 - accuracy: 0.8182 - precision: 0.8182 - recall: 0.8182 - val_loss: 0.7184 - val_accuracy: 0.7200 - val_precision: 0.7200 - val_recall: 0.7200
# Epoch 3/100
# 7/7 [==============================] - ETA: 0s - loss: 0.2469 - accuracy: 0.9343 - precision: 0.9343 - recall: 0.9343
# Epoch 3: val_accuracy improved from 0.80000 to 0.84000, saving model to best_model_LeNet.h5
# 7/7 [==============================] - 7s 1s/step - loss: 0.2469 - accuracy: 0.9343 - precision: 0.9343 - recall: 0.9343 - val_loss: 0.4034 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 4/100
# 7/7 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293
# Epoch 4: val_accuracy did not improve from 0.84000
# 7/7 [==============================] - 7s 960ms/step - loss: 0.1623 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - val_loss: 0.4806 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 5/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9949 - precision: 0.9949 - recall: 0.9949
# Epoch 5: val_accuracy improved from 0.84000 to 0.88000, saving model to best_model_LeNet.h5
# 7/7 [==============================] - 7s 1s/step - loss: 0.0561 - accuracy: 0.9949 - precision: 0.9949 - recall: 0.9949 - val_loss: 0.3547 - val_accuracy: 0.8800 - val_precision: 0.8800 - val_recall: 0.8800
# Epoch 6/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 6: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 7s 1s/step - loss: 0.0204 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3823 - val_accuracy: 0.8800 - val_precision: 0.8800 - val_recall: 0.8800
# Epoch 7/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 7: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 7s 1s/step - loss: 0.0051 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.4814 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 8/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 8: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 7s 1s/step - loss: 0.0021 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.4871 - val_accuracy: 0.8800 - val_precision: 0.8800 - val_recall: 0.8800
# Epoch 9/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 9: val_accuracy improved from 0.88000 to 0.92000, saving model to best_model_LeNet.h5
# 7/7 [==============================] - 7s 1s/step - loss: 0.0010 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.4822 - val_accuracy: 0.9200 - val_precision: 0.9200 - val_recall: 0.9200
# Epoch 10/100
# 7/7 [==============================] - ETA: 0s - loss: 6.
-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8639 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 70/100
# 7/7 [==============================] - ETA: 0s - loss: 8.7020e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 70: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 7s 1s/step - loss: 8.7020e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8661 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 71/100
# 7/7 [==============================] - ETA: 0s - loss: 8.4347e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 71: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 8s 1s/step - loss: 8.4347e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8654 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 72/100
# 7/7 [==============================] - ETA: 0s - loss: 8.1873e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 72: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 9s 1s/step - loss: 8.1873e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8682 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 73/100
# 7/7 [==============================] - ETA: 0s - loss: 7.8995e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 73: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 10s 1s/step - loss: 7.8995e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8718 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 74/100
# 7/7 [==============================] - ETA: 0s - loss: 7.6461e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 74: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 9s 1s/step - loss: 7.6461e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8702 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 75/100
# 7/7 [==============================] - ETA: 0s - loss: 7.4191e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 75: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 8s 1s/step - loss: 7.4191e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8717 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 76/100
# 7/7 [==============================] - ETA: 0s - loss: 7.2120e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 76: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 9s 1s/step - loss: 7.2120e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8770 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 77/100
# 7/7 [==============================] - ETA: 0s - loss: 6.9670e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 77: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 8s 1s/step - loss: 6.9670e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8811 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 78/100
# 7/7 [==============================] - ETA: 0s - loss: 6.7683e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 78: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 8s 1s/step - loss: 6.7683e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8806 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 79/100
# 7/7 [==============================] - ETA: 0s - loss: 6.5666e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 79: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 8s 1s/step - loss: 6.5666e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8791 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 80/100
# 7/7 [==============================] - ETA: 0s - loss: 6.4137e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 80: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 8s 1s/step - loss: 6.4137e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8722 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 81/100
# 7/7 [==============================] - ETA: 0s - loss: 6.2252e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 81: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 9s 1s/step - loss: 6.2252e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8730 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 82/100
# 7/7 [==============================] - ETA: 0s - loss: 6.0290e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 82: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 9s 1s/step - loss: 6.0290e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8803 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 83/100
# 7/7 [==============================] - ETA: 0s - loss: 5.8821e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 83: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 8s 1s/step - loss: 5.8821e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8841 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 84/100
# 7/7 [==============================] - ETA: 0s - loss: 5.7063e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 84: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 8s 1s/step - loss: 5.7063e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8843 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 85/100
# 7/7 [==============================] - ETA: 0s - loss: 5.5762e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 85: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 8s 1s/step - loss: 5.5762e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8857 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 86/100
# 7/7 [==============================] - ETA: 0s - loss: 5.4221e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 86: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 8s 1s/step - loss: 5.4221e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8878 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 87/100
# 7/7 [==============================] - ETA: 0s - loss: 5.2933e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 87: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 9s 1s/step - loss: 5.2933e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8893 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 88/100
# 7/7 [==============================] - ETA: 0s - loss: 5.1530e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 88: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 8s 1s/step - loss: 5.1530e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8929 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 89/100
# 7/7 [==============================] - ETA: 0s - loss: 5.0392e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 89: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 9s 1s/step - loss: 5.0392e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8950 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 90/100
# 7/7 [==============================] - ETA: 0s - loss: 4.8887e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 90: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 9s 1s/step - loss: 4.8887e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8944 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 91/100
# 7/7 [==============================] - ETA: 0s - loss: 4.7755e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 91: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 10s 1s/step - loss: 4.7755e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8946 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 92/100
# 7/7 [==============================] - ETA: 0s - loss: 4.6491e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 92: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 9s 1s/step - loss: 4.6491e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8971 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 93/100
# 7/7 [==============================] - ETA: 0s - loss: 4.5564e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 93: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 8s 1s/step - loss: 4.5564e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9011 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 94/100
# 7/7 [==============================] - ETA: 0s - loss: 4.4390e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 94: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 9s 1s/step - loss: 4.4390e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9006 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 95/100
# 7/7 [==============================] - ETA: 0s - loss: 4.3246e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 95: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 11s 2s/step - loss: 4.3246e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9022 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 96/100
# 7/7 [==============================] - ETA: 0s - loss: 4.2391e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 96: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 10s 1s/step - loss: 4.2391e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9046 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 97/100
# 7/7 [==============================] - ETA: 0s - loss: 4.1277e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 97: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 10s 1s/step - loss: 4.1277e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9075 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 98/100
# 7/7 [==============================] - ETA: 0s - loss: 4.0374e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 98: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 9s 1s/step - loss: 4.0374e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9097 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 99/100
# 7/7 [==============================] - ETA: 0s - loss: 3.9519e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 99: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 10s 1s/step - loss: 3.9519e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9096 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400
# Epoch 100/100
# 7/7 [==============================] - ETA: 0s - loss: 3.8465e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 100: val_accuracy did not improve from 0.92000
# 7/7 [==============================] - 11s 1s/step - loss: 3.8465e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9099 - val_accuracy: 0.8400 - val_precision: 0.8400 - val_recall: 0.8400

# %% [markdown]
# ## Evaluate the Model

# %%
model.load_weights('best_model_LeNet.h5')
test_loss, test_acc ,test_prec, test_recall= model.evaluate(test_generator)
print("Test Accuracy:", test_acc)
print("Test Precision:", test_prec)
print("Test F1-score:", test_recall)
# Out:
# 1/1 [==============================] - 0s 389ms/step - loss: 1.1343 - accuracy: 0.7308 - precision: 0.7308 - recall: 0.7308
# Test Accuracy: 0.7307692170143127
# Test Precision: 0.7307692170143127
# Test F1-score: 0.7307692170143127

# %% [markdown]
# ## Model Metrics

# %%
Y_pred = model.predict(test_generator)
y_pred = tf.argmax(Y_pred, axis=1)
print("Classification Report:\n", classification_report(test_generator.classes, y_pred.numpy()))
# Out:
# 1/1 [==============================] - 1s 912ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.65      0.76      0.70        17
#            1       0.33      0.22      0.27         9
#
#     accuracy                           0.58        26
#    macro avg       0.49      0.49      0.48        26
# weighted avg       0.54      0.58      0.55        26

# %%
from sklearn.metrics import confusion_matrix, classification_report
conf_matrix = confusion_matrix(test_generator.classes, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[13  4]
#  [ 7  2]]

# %% [markdown]
# ## Visualize

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 3))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
def plot_precision_recall(history):
    plt.figure(figsize=(12, 3))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history['precision'], label='Training Precision')
    plt.plot(history.history['val_precision'], label='Validation Precision')
    plt.xlabel('Epoch')
    plt.ylabel('Precision')
    plt.title('Training and Validation Precision')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['recall'], label='Training Recall')
    plt.plot(history.history['val_recall'], label='Validation Recall')
    plt.xlabel('Epoch')
    plt.ylabel('Recall')
    plt.title('Training and Validation Recall')
    plt.legend()

    plt.show()

plot_precision_recall(history)
